# %% [markdown]
# ### Ridge Regression Model With Hyperparameter and Feature Selection ###

# %%
import numpy as np

from sklearn.metrics import make_scorer, mean_squared_error, mean_absolute_error
from sklearn.feature_selection import RFECV
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Ridge, LinearRegression, Lasso, ElasticNet
from sklearn.ensemble import RandomForestRegressor, BaggingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split
from Utils import *

# %% [markdown]
# #### Loading the Training and Testing Data ###

# %%
train = np.load('../Models/train.npy')

X = train[0:,0:-1]
y = train[:, -1]

X_train = np.load('../Models/X_train.npy')
y_train = np.load('../Models/y_train.npy')
X_test = np.load('../Models/X_test.npy')
y_test = np.load('../Models/y_test.npy')

# %%
rfecv_mae = RFECV(estimator=LinearRegression(), step=1, cv=10, scoring=mae_scorer_gs)
rfecv_rmse = RFECV(estimator=LinearRegression(), step=1, cv=10, scoring=rmse_scorer_gs)

rfecv_mae = rfecv_mae.fit(X_train, y_train)
rfecv_rmse = rfecv_rmse.fit(X_train, y_train)

prediction_mae = rfecv_mae.predict(X_test)
prediction_rmse = rfecv_rmse.predict(X_test)

print 'MAE {0}'.format(absolute_error(y_test, prediction_mae))
print 'RMSE {0}'.format(root_mean_squared(y_test, prediction_rmse))

# best_estim = rfecv.estimator_
# Out:
# MAE 3.55857969394
# RMSE 4.58429548429

# %%
parameters = {
    'alpha': [0.01, 0.1, 1.0, 10, 100],
    'normalize': [True, False],
    'fit_intercept': [True, False]
}

# %%
import pandas as pd
df_data = pd.read_csv("../feature_engineered_dataset.csv")
feature_names = df_data.columns
import operator

# %%
def get_best_estimator(estimator, step, cv, scoring, parameters):
    clf_mae = GridSearchCV(estimator=estimator, param_grid=parameters, cv=cv, scoring=scoring, n_jobs=-1, verbose=10)
    clf_mae.fit(X_train, y_train)
    return clf_mae.best_estimator_

# %%
ridge = Ridge()
best_ridge = get_best_estimator(ridge, 1, 10, mae_scorer_gs, parameters)

print best_ridge
# Out:
# Fitting 10 folds for each of 20 candidates, totalling 200 fits
# [CV] normalize=True, alpha=0.01, fit_intercept=True ..................
# [CV]  normalize=True, alpha=0.01, fit_intercept=True, score=-3.324433, total=   0.0s
# [CV] normalize=True, alpha=0.01, fit_intercept=True ..................
# [CV] normalize=True, alpha=0.01, fit_intercept=True ..................
# [CV] normalize=True, alpha=0.01, fit_intercept=True ..................
# [CV] normalize=True, alpha=0.01, fit_intercept=True ..................
# [CV]  normalize=True, alpha=0.01, fit_intercept=True, score=-3.930391, total=   0.0s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.0485s.) Setting batch_size=8.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.0485s.) Setting batch_size=64.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.1s
# [CV]  normalize=True, alpha=0.01, fit_intercept=True, score=-3.644707, total=   0.0s
# [CV]  normalize=True, alpha=0.01, fit_intercept=True, score=-3.754051, total=   0.0s
# [CV] normalize=True, alpha=0.01, fit_intercept=True ..................
# [CV] normalize=True, alpha=0.01, fit_intercept=True ..................
# [CV] normalize=True, alpha=0.01, fit_intercept=True ..................
# [CV]  normalize=True, alpha=0.01, fit_intercept=True, score=-3.739443, total=   0.0s
# [CV] normalize=True, alpha=0.01, fit_intercept=True ..................
# [CV]  normalize=True, alpha=0.01, fit_intercept=True, score=-3.755577, total=   0.0s
# [CV]  normalize=True, alpha=0.01, fit_intercept=True, score=-3.372890, total=   0.0s
# [CV]  normalize=True, alpha=0.01, fit_intercept=True, score=-3.593802, total=   0.0s
# [CV]  normalize=True, alpha=0.01, fit_intercept=True, score=-3.818839, total=   0.0s
# [CV] normalize=True, alpha=0.01, fit_intercept=True ..................
# [CV]  normalize=True, alpha=0.01, fit_intercept=True, score=-3.331968, total=   0.0s
# [CV] normalize=False, alpha=0.01, fit_intercept=True .................
# [CV]  normalize=False, alpha=0.01, fit_intercept=True, score=-3.304535, total=   0.0s
# [CV] normalize=False, alpha=0.01, fit_intercept=True .................
# [CV] normalize=False, alpha=0.01, fit_intercept=True .................
# [CV]  normalize=False, alpha=0.01, fit_intercept=True, score=-3.897347, total=   0.0s
# [CV]  normalize=False, alpha=0.01, fit_intercept=True, score=-3.623084, total=   0.0s
# [CV] normalize=False, alpha=0.01, fit_intercept=True .................
# [CV]  normalize=False, alpha=0.01, fit_intercept=True, score=-3.765563, total=   0.0s
# [CV] normalize=False, alpha=0.01, fit_intercept=True .................
# [CV]  normalize=False, alpha=0.01, fit_intercept=True, score=-3.702777, total=   0.0s
# [CV] normalize=False, alpha=0.01, fit_intercept=True .................
# [CV]  normalize=False, alpha=0.01, fit_intercept=True, score=-3.795573, total=   0.0s
# [CV] normalize=False, alpha=0.01, fit_intercept=True .................
# [CV]  normalize=False, alpha=0.01, fit_intercept=True, score=-3.404812, total=   0.0s
# [CV] normalize=False, alpha=0.01, fit_intercept=True .................
# [CV]  normalize=False, alpha=0.01, fit_intercept=True, score=-3.592428, total=   0.0s
# [CV] normalize=False, alpha=0.01, fit_intercept=True .................
# [CV]  normalize=False, alpha=0.01, fit_intercept=True, score=-3.797311, total=   0.0s
# [CV] normalize=False, alpha=0.01, fit_intercept=True .................
# [CV]  normalize=False, alpha=0.01, fit_intercept=True, score=-3.360255, total=   0.0s
# [CV] normalize=True, alpha=0.01, fit_intercept=False .................
# [CV]  normalize=True, alpha=0.01, fit_intercept=False, score=-3.305283, total=   0.0s
# [CV] normalize=True, alpha=0.01, fit_intercept=False .................
# [CV]  normalize=True, alpha=0.01, fit_intercept=False, score=-3.897299, total=   0.0s
# [CV] normalize=True, alpha=0.01, fit_intercept=False .................
# [CV]  normalize=True, alpha=0.01, fit_intercept=False, score=-3.624270, total=   0.0s
# [CV] normalize=True, alpha=0.01, fit_intercept=False .................
# [CV] normalize=True, alpha=0.01, fit_intercept=False .................
# [CV]  normalize=True, alpha=0.01, fit_intercept=False, score=-3.698180, total=   0.0s
# [CV] normalize=True, alpha=0.01, fit_intercept=False .................
# [CV]  normalize=True, alpha=0.01, fit_intercept=False, score=-3.768402, total=   0.0s
# [CV]  normalize=True, alpha=0.01, fit_intercept=False, score=-3.795760, total=   0.0s
# [CV] normalize=True, alpha=0.01, fit_intercept=False .................
# [CV]  normalize=True, alpha=0.01, fit_intercept=False, score=-3.400109, total=   0.0s
# [CV] normalize=True, alpha=0.01, fit_intercept=False .................
# [CV]  normalize=True, alpha=0.01, fit_intercept=False, score=-3.593355, total=   0.0s
# [CV] normalize=True, alpha=0.01, fit_intercept=False .................
# [CV]  normalize=True, alpha=0.01, fit_intercept=False, score=-3.798238, total=   0.0s
# [CV] normalize=True, alpha=0.01, fit_intercept=False .................
# [CV]  normalize=True, alpha=0.01, fit_intercept=False, score=-3.356850, total=   0.0s
# [CV] normalize=False, alpha=0.01, fit_intercept=False ................
# [CV]  normalize=False, alpha=0.01, fit_intercept=False, score=-3.305283, total=   0.0s
# [CV] normalize=False, alpha=0.01, fit_intercept=False ................
# [CV]  normalize=False, alpha=0.01, fit_intercept=False, score=-3.897299, total=   0.0s
# [CV] normalize=False, alpha=0.01, fit_intercept=False ................
# [CV]  normalize=False, alpha=0.01, fit_intercept=False, score=-3.624270, total=   0.0s
# [CV] normalize=False, alpha=0.01, fit_intercept=False ................
# [CV]  normalize=False, alpha=0.01, fit_intercept=False, score=-3.768402, total=   0.0s
# [CV] normalize=False, alpha=0.01, fit_intercept=False ................
# [CV]  normalize=False, alpha=0.01, fit_intercept=False, score=-3.698180, total=   0.0s
# [CV] normalize=False, alpha=0.01, fit_intercept=False ................
# [CV]  normalize=False, alpha=0.01, fit_intercept=False, score=-3.795760, total=   0.0s
# [CV] normalize=False, alpha=0.01, fit_intercept=False ................
# [CV]  normalize=False, alpha=0.01, fit_intercept=False, score=-3.400109, total=   0.0s
# [CV] normalize=False, alpha=0.01, fit_intercept=False ................
# [CV]  normalize=False, alpha=0.01, fit_intercept=False, score=-3.593355, total=   0.0s
# [CV] normalize=False, alpha=0.01, fit_intercept=False ................
# [CV]  normalize=False, alpha=0.01, fit_intercept=False, score=-3.798238, total=   0.0s
# [CV] normalize=False, alpha=0.01, fit_intercept=False ................
# [CV]  normalize=False, alpha=0.01, fit_intercept=False, score=-3.356850, total=   0.0s
# [CV] normalize=True, alpha=0.1, fit_intercept=True ...................
# [CV] normalize=True, alpha=1.0, fit_intercept=True ...................
# [CV]  normalize=True, alpha=0.1, fit_intercept=True, score=-3.384156, total=   0.0s
# [CV] normalize=True, alpha=0.1, fit_intercept=True ...................
# [CV]  normalize=True, alpha=1.0, fit_intercept=True, score=-3.856697, total=   0.0s
# [CV] normalize=True, alpha=1.0, fit_intercept=True ...................
# [CV]  normalize=True, alpha=0.1, fit_intercept=True, score=-3.977226, total=   0.0s
# [CV] normalize=True, alpha=0.1, fit_intercept=True ...................
# [CV]  normalize=True, alpha=1.0, fit_intercept=True, score=-3.472791, total=   0.0s
# [CV] normalize=False, alpha=1.0, fit_intercept=True ..................
# [CV]  normalize=True, alpha=0.1, fit_intercept=True, score=-3.679056, total=   0.0s
# [CV] normalize=True, alpha=0.1, fit_intercept=True ...................
# [CV]  normalize=False, alpha=1.0, fit_intercept=True, score=-3.316064, total=   0.0s
# [CV] normalize=False, alpha=1.0, fit_intercept=True ..................
# [CV]  normalize=True, alpha=0.1, fit_intercept=True, score=-3.796227, total=   0.0s
# [CV] normalize=True, alpha=0.1, fit_intercept=True ...................
# [CV]  normalize=False, alpha=1.0, fit_intercept=True, score=-3.908800, total=   0.0s
# [CV] normalize=False, alpha=1.0, fit_intercept=True ..................
# [CV]  normalize=True, alpha=0.1, fit_intercept=True, score=-3.738091, total=   0.0s
# [CV] normalize=True, alpha=0.1, fit_intercept=True ...................
# [CV]  normalize=False, alpha=1.0, fit_intercept=True, score=-3.627701, total=   0.0s
# [CV] normalize=False, alpha=1.0, fit_intercept=True ..................
# [CV]  normalize=True, alpha=0.1, fit_intercept=True, score=-3.699400, total=   0.0s
# [CV]  normalize=False, alpha=1.0, fit_intercept=True, score=-3.717966, total=   0.0s
# [CV] normalize=True, alpha=0.1, fit_intercept=True ...................
# [CV] normalize=False, alpha=1.0, fit_intercept=True ..................
# [CV]  normalize=False, alpha=1.0, fit_intercept=True, score=-3.679614, total=   0.0s
# [CV]  normalize=True, alpha=0.1, fit_intercept=True, score=-3.411861, total=   0.0s
# [CV] normalize=False, alpha=1.0, fit_intercept=True ..................
# [CV] normalize=True, alpha=0.1, fit_intercept=True ...................
# [CV]  normalize=False, alpha=1.0, fit_intercept=True, score=-3.759333, total=   0.0s
# [CV]  normalize=True, alpha=0.1, fit_intercept=True, score=-3.574228, total=   0.0s
# [CV] normalize=False, alpha=1.0, fit_intercept=True ..................
# [CV] normalize=True, alpha=0.1, fit_intercept=True ...................
# [CV]  normalize=True, alpha=0.1, fit_intercept=True, score=-3.846797, total=   0.0s
# [CV]  normalize=False, alpha=1.0, fit_intercept=True, score=-3.402028, total=   0.0s
# [CV] normalize=False, alpha=1.0, fit_intercept=True ..................
# [CV] normalize=True, alpha=0.1, fit_intercept=True ...................
# [CV]  normalize=False, alpha=1.0, fit_intercept=True, score=-3.586970, total=   0.0s
# [CV]  normalize=True, alpha=0.1, fit_intercept=True, score=-3.357078, total=   0.0s
# [CV] normalize=False, alpha=0.1, fit_intercept=True ..................
# [CV] normalize=False, alpha=1.0, fit_intercept=True ..................
# [CV]  normalize=False, alpha=1.0, fit_intercept=True, score=-3.797287, total=   0.0s
# [CV]  normalize=False, alpha=0.1, fit_intercept=True, score=-3.307758, total=   0.0s
# [CV] normalize=False, alpha=0.1, fit_intercept=True ..................
# [CV] normalize=False, alpha=1.0, fit_intercept=True ..................
# [CV]  normalize=False, alpha=0.1, fit_intercept=True, score=-3.900525, total=   0.0s
# [CV]  normalize=False, alpha=1.0, fit_intercept=True, score=-3.372726, total=   0.0s
# [CV] normalize=True, alpha=1.0, fit_intercept=False ..................
# [CV] normalize=False, alpha=0.1, fit_intercept=True ..................
# [CV]  normalize=True, alpha=1.0, fit_intercept=False, score=-3.595705, total=   0.0s
# [CV]  normalize=False, alpha=0.1, fit_intercept=True, score=-3.623761, total=   0.0s
# [CV] normalize=True, alpha=1.0, fit_intercept=False ..................
# [CV] normalize=False, alpha=0.1, fit_intercept=True ..................
# [CV]  normalize=True, alpha=1.0, fit_intercept=False, score=-3.995021, total=   0.0s
# [CV]  normalize=False, alpha=0.1, fit_intercept=True, score=-3.747488, total=   0.0s
# [CV] normalize=False, alpha=0.1, fit_intercept=True ..................
# [CV] normalize=True, alpha=1.0, fit_intercept=False ..................
# [CV]  normalize=True, alpha=1.0, fit_intercept=False, score=-3.777177, total=   0.0s
# [CV] normalize=False, alpha=10, fit_intercept=False ..................
# [CV]  normalize=False, alpha=0.1, fit_intercept=True, score=-3.700086, total=   0.0s
# [CV] normalize=True, alpha=1.0, fit_intercept=False ..................
# [CV] normalize=False, alpha=0.1, fit_intercept=True ..................
# [CV]  normalize=False, alpha=10, fit_intercept=False, score=-4.079801, total=   0.0s
# [CV]  normalize=True, alpha=1.0, fit_intercept=False, score=-3.972527, total=   0.0s
# [CV] normalize=False, alpha=10, fit_intercept=False ..................
# [CV] normalize=True, alpha=1.0, fit_intercept=False ..................
# [CV]  normalize=False, alpha=0.1, fit_intercept=True, score=-3.786777, total=   0.0s
# [CV] normalize=False, alpha=0.1, fit_intercept=True ..................
# [CV]  normalize=False, alpha=10, fit_intercept=False, score=-4.382469, total=   0.0s
# [CV]  normalize=True, alpha=1.0, fit_intercept=False, score=-3.876332, total=   0.0s
# [CV] normalize=False, alpha=10, fit_intercept=False ..................
# [CV] normalize=True, alpha=1.0, fit_intercept=False ..................
# [CV]  normalize=False, alpha=0.1, fit_intercept=True, score=-3.405575, total=   0.0s
# [CV] normalize=False, alpha=0.1, fit_intercept=True ..................
# [CV]  normalize=False, alpha=10, fit_intercept=False, score=-4.430731, total=   0.0s
# [CV]  normalize=True, alpha=1.0, fit_intercept=False, score=-4.073842, total=   0.0s
# [CV] normalize=True, alpha=1.0, fit_intercept=False ..................
# [CV] normalize=False, alpha=10, fit_intercept=False ..................
# [CV]  normalize=False, alpha=0.1, fit_intercept=True, score=-3.590619, total=   0.0s
# [CV]  normalize=False, alpha=10, fit_intercept=False, score=-4.493046, total=   0.0s
# [CV]  normalize=True, alpha=1.0, fit_intercept=False, score=-3.377519, total=   0.0s
# [CV] normalize=False, alpha=0.1, fit_intercept=True ..................
# [CV] normalize=False, alpha=10, fit_intercept=False ..................
# [CV] normalize=True, alpha=1.0, fit_intercept=False ..................
# [CV]  normalize=False, alpha=0.1, fit_intercept=True, score=-3.796987, total=   0.0s
# [CV]  normalize=True, alpha=1.0, fit_intercept=False, score=-3.751066, total=   0.0s
# [CV]  normalize=False, alpha=10, fit_intercept=False, score=-3.636051, total=   0.0s
# [CV] normalize=False, alpha=0.1, fit_intercept=True ..................
# [CV] normalize=True, alpha=1.0, fit_intercept=False ..................
# [CV] normalize=False, alpha=10, fit_intercept=False ..................
# [CV]  normalize=False, alpha=0.1, fit_intercept=True, score=-3.363374, total=   0.0s
# [CV]  normalize=True, alpha=1.0, fit_intercept=False, score=-4.111658, total=   0.0s
# [CV]  normalize=False, alpha=10, fit_intercept=False, score=-4.132482, total=   0.0s
# [CV] normalize=True, alpha=1.0, fit_intercept=False ..................
# [CV] normalize=False, alpha=10, fit_intercept=False ..................
# [CV] normalize=True, alpha=0.1, fit_intercept=False ..................
# [CV]  normalize=True, alpha=1.0, fit_intercept=False, score=-3.552031, total=   0.0s
# [CV]  normalize=True, alpha=0.1, fit_intercept=False, score=-3.322632, total=   0.0s
# [CV]  normalize=False, alpha=10, fit_intercept=False, score=-4.613265, total=   0.0s
# [CV] normalize=False, alpha=10, fit_intercept=False ..................
# [CV] normalize=False, alpha=1.0, fit_intercept=False .................
# [CV] normalize=True, alpha=0.1, fit_intercept=False ..................
# [CV]  normalize=False, alpha=1.0, fit_intercept=False, score=-3.595705, total=   0.0s
# [CV]  normalize=False, alpha=10, fit_intercept=False, score=-4.007575, total=   0.0s
# [CV]  normalize=True, alpha=0.1, fit_intercept=False, score=-3.900985, total=   0.0s
# [CV] normalize=True, alpha=100, fit_intercept=True ...................
# [CV] normalize=True, alpha=0.1, fit_intercept=False ..................
# [CV] normalize=False, alpha=1.0, fit_intercept=False .................
# [CV]  normalize=True, alpha=0.1, fit_intercept=False, score=-3.635092, total=   0.0s
# [CV]  normalize=False, alpha=1.0, fit_intercept=False, score=-3.995021, total=   0.0s
# [CV]  normalize=True, alpha=100, fit_intercept=True, score=-5.518301, total=   0.0s
# [CV] normalize=False, alpha=1.0, fit_intercept=False .................
# [CV] normalize=True, alpha=0.1, fit_intercept=False ..................
# [CV] normalize=True, alpha=100, fit_intercept=True ...................
# [CV]  normalize=False, alpha=1.0, fit_intercept=False, score=-3.777177, total=   0.0s
# [CV]  normalize=True, alpha=0.1, fit_intercept=False, score=-3.776553, total=   0.0s
# [CV] normalize=False, alpha=1.0, fit_intercept=False .................
# [CV]  normalize=True, alpha=100, fit_intercept=True, score=-5.878975, total=   0.0s
# [CV] normalize=True, alpha=0.1, fit_intercept=False ..................
# [CV] normalize=True, alpha=100, fit_intercept=True ...................
# [CV]  normalize=False, alpha=1.0, fit_intercept=False, score=-3.972527, total=   0.0s
# [CV]  normalize=True, alpha=0.1, fit_intercept=False, score=-3.665903, total=   0.0s
# [CV] normalize=True, alpha=0.1, fit_intercept=False ..................
# [CV] normalize=False, alpha=1.0, fit_intercept=False .................
# [CV]  normalize=True, alpha=100, fit_intercept=True, score=-6.166797, total=   0.0s
# [CV] normalize=True, alpha=100, fit_intercept=True ...................
# [CV]  normalize=True, alpha=0.1, fit_intercept=False, score=-3.804330, total=   0.0s
# [CV]  normalize=False, alpha=1.0, fit_intercept=False, score=-3.876332, total=   0.0s
# [CV] normalize=True, alpha=0.1, fit_intercept=False ..................
# [CV] normalize=False, alpha=1.0, fit_intercept=False .................
# [CV]  normalize=True, alpha=100, fit_intercept=True, score=-6.104704, total=   0.0s
# [CV]  normalize=True, alpha=0.1, fit_intercept=False, score=-3.369252, total=   0.0s
# [CV] normalize=True, alpha=100, fit_intercept=True ...................
# [CV]  normalize=False, alpha=1.0, fit_intercept=False, score=-4.073842, total=   0.0s
# [CV] normalize=True, alpha=0.1, fit_intercept=False ..................
# [CV] normalize=False, alpha=1.0, fit_intercept=False .................
# [CV]  normalize=True, alpha=100, fit_intercept=True, score=-5.379016, total=   0.0s
# [CV]  normalize=True, alpha=0.1, fit_intercept=False, score=-3.607390, total=   0.0s
# [CV]  normalize=False, alpha=1.0, fit_intercept=False, score=-3.377519, total=   0.0s
# [CV] normalize=True, alpha=0.1, fit_intercept=False ..................
# [CV] normalize=True, alpha=100, fit_intercept=True ...................
# [CV] normalize=False, alpha=1.0, fit_intercept=False .................
# [CV]  normalize=True, alpha=0.1, fit_intercept=False, score=-3.820612, total=   0.0s
# [CV]  normalize=False, alpha=1.0, fit_intercept=False, score=-3.751066, total=   0.0s
# [CV]  normalize=True, alpha=100, fit_intercept=True, score=-5.689668, total=   0.0s
# [CV] normalize=True, alpha=0.1, fit_intercept=False ..................
# [CV] normalize=False, alpha=1.0, fit_intercept=False .................
# [CV] normalize=True, alpha=100, fit_intercept=True ...................
# [CV]  normalize=True, alpha=0.1, fit_intercept=False, score=-3.345207, total=   0.0s
# [CV]  normalize=False, alpha=1.0, fit_intercept=False, score=-4.111658, total=   0.0s
# [CV] normalize=False, alpha=0.1, fit_intercept=False .................
# [CV]  normalize=True, alpha=100, fit_intercept=True, score=-5.732792, total=   0.0s
# [CV] normalize=False, alpha=1.0, fit_intercept=False .................
# [CV] normalize=True, alpha=100, fit_intercept=True ...................
# [CV]  normalize=False, alpha=1.0, fit_intercept=False, score=-3.552031, total=   0.0s
# [CV]  normalize=False, alpha=0.1, fit_intercept=False, score=-3.322632, total=   0.0s
# [CV] normalize=True, alpha=10, fit_intercept=True ....................
# [CV] normalize=False, alpha=0.1, fit_intercept=False .................
# [CV]  normalize=True, alpha=100, fit_intercept=True, score=-5.217953, total=   0.0s
# [CV] normalize=True, alpha=100, fit_intercept=True ...................
# [CV]  normalize=False, alpha=0.1, fit_intercept=False, score=-3.900985, total=   0.0s
# [CV]  normalize=True, alpha=10, fit_intercept=True, score=-4.046183, total=   0.0s
# [CV] normalize=True, alpha=10, fit_intercept=True ....................
# [CV] normalize=False, alpha=0.1, fit_intercept=False .................
# [CV]  normalize=True, alpha=100, fit_intercept=True, score=-5.869622, total=   0.0s
# [CV] normalize=True, alpha=100, fit_intercept=True ...................
# [CV]  normalize=False, alpha=0.1, fit_intercept=False, score=-3.635092, total=   0.0s
# [CV]  normalize=True, alpha=10, fit_intercept=True, score=-4.556062, total=   0.0s
# [CV] normalize=False, alpha=0.1, fit_intercept=False .................
# [CV] normalize=True, alpha=10, fit_intercept=True ....................
# [CV]  normalize=True, alpha=100, fit_intercept=True, score=-5.977250, total=   0.0s
# [CV]  normalize=False, alpha=0.1, fit_intercept=False, score=-3.776553, total=   0.0s
# [CV] normalize=False, alpha=100, fit_intercept=True ..................
# [CV] normalize=False, alpha=0.1, fit_intercept=False .................
# [CV]  normalize=True, alpha=10, fit_intercept=True, score=-4.467585, total=   0.0s
# [CV] normalize=True, alpha=10, fit_intercept=True ....................
# [CV]  normalize=False, alpha=100, fit_intercept=True, score=-3.408045, total=   0.0s
# [CV]  normalize=False, alpha=0.1, fit_intercept=False, score=-3.665903, total=   0.0s
# [CV] normalize=False, alpha=100, fit_intercept=True ..................
# [CV] normalize=False, alpha=0.1, fit_intercept=False .................
# [CV]  normalize=True, alpha=10, fit_intercept=True, score=-4.515514, total=   0.0s
# [CV]  normalize=False, alpha=100, fit_intercept=True, score=-3.944179, total=   0.0s
# [CV] normalize=True, alpha=10, fit_intercept=True ....................
# [CV]  normalize=False, alpha=0.1, fit_intercept=False, score=-3.804330, total=   0.0s
# [CV] normalize=False, alpha=100, fit_intercept=True ..................
# [CV] normalize=False, alpha=0.1, fit_intercept=False .................
# [CV]  normalize=True, alpha=10, fit_intercept=True, score=-4.116974, total=   0.0s
# [CV]  normalize=False, alpha=100, fit_intercept=True, score=-3.653181, total=   0.0s
# [CV]  normalize=False, alpha=0.1, fit_intercept=False, score=-3.369252, total=   0.0s
# [CV] normalize=True, alpha=10, fit_intercept=True ....................
# [CV] normalize=False, alpha=100, fit_intercept=True ..................
# [CV] normalize=False, alpha=0.1, fit_intercept=False .................
# [CV]  normalize=False, alpha=100, fit_intercept=True, score=-3.816530, total=   0.0s
# [CV]  normalize=False, alpha=0.1, fit_intercept=False, score=-3.607390, total=   0.0s
# [CV]  normalize=True, alpha=10, fit_intercept=True, score=-4.056127, total=   0.0s
# [CV] normalize=True, alpha=10, fit_intercept=True ....................
# [CV] normalize=False, alpha=0.1, fit_intercept=False .................
# [CV] normalize=False, alpha=100, fit_intercept=True ..................
# [CV]  normalize=False, alpha=0.1, fit_intercept=False, score=-3.820612, total=   0.0s
# [CV]  normalize=False, alpha=100, fit_intercept=True, score=-3.680303, total=   0.0s
# [CV]  normalize=True, alpha=10, fit_intercept=True, score=-4.084576, total=   0.0s
# [CV] normalize=False, alpha=100, fit_intercept=True ..................
# [CV] normalize=False, alpha=0.1, fit_intercept=False .................
# [CV] normalize=True, alpha=10, fit_intercept=True ....................
# [CV]  normalize=False, alpha=100, fit_intercept=True, score=-3.718830, total=   0.0s
# [CV]  normalize=False, alpha=0.1, fit_intercept=False, score=-3.345207, total=   0.0s
# [CV] normalize=False, alpha=100, fit_intercept=True ..................
# [CV] normalize=True, alpha=1.0, fit_intercept=True ...................
# [CV]  normalize=True, alpha=10, fit_intercept=True, score=-3.842719, total=   0.0s
# [CV] normalize=True, alpha=10, fit_intercept=True ....................
# [CV]  normalize=False, alpha=100, fit_intercept=True, score=-3.418948, total=   0.0s
# [CV]  normalize=True, alpha=1.0, fit_intercept=True, score=-3.502408, total=   0.0s
# [CV] normalize=False, alpha=100, fit_intercept=True ..................
# [CV] normalize=True, alpha=1.0, fit_intercept=True ...................
# [CV]  normalize=True, alpha=10, fit_intercept=True, score=-4.208706, total=   0.0s
# [CV] normalize=True, alpha=10, fit_intercept=True ....................
# [CV]  normalize=False, alpha=100, fit_intercept=True, score=-3.578812, total=   0.0s
# [CV]  normalize=True, alpha=1.0, fit_intercept=True, score=-4.061980, total=   0.0s
# [CV] normalize=True, alpha=1.0, fit_intercept=True ...................
# [CV] normalize=False, alpha=100, fit_intercept=True ..................
# [CV]  normalize=True, alpha=10, fit_intercept=True, score=-4.198663, total=   0.0s
# [CV]  normalize=False, alpha=100, fit_intercept=True, score=-3.876076, total=   0.0s
# [CV] normalize=False, alpha=10, fit_intercept=True ...................
# [CV]  normalize=True, alpha=1.0, fit_intercept=True, score=-3.744778, total=   0.0s
# [CV] normalize=False, alpha=100, fit_intercept=True ..................
# [CV] normalize=True, alpha=1.0, fit_intercept=True ...................
# [CV]  normalize=False, alpha=10, fit_intercept=True, score=-3.338853, total=   0.0s
# [CV]  normalize=False, alpha=100, fit_intercept=True, score=-3.382992, total=   0.0s
# [CV] normalize=False, alpha=10, fit_intercept=True ...................
# [CV] normalize=True, alpha=100, fit_intercept=False ..................
# [CV]  normalize=True, alpha=1.0, fit_intercept=True, score=-3.881623, total=   0.0s
# [CV] normalize=True, alpha=1.0, fit_intercept=True ...................
# [CV]  normalize=False, alpha=10, fit_intercept=True, score=-3.910305, total=   0.0s
# [CV]  normalize=True, alpha=100, fit_intercept=False, score=-4.549204, total=   0.0s
# [CV] normalize=True, alpha=100, fit_intercept=False ..................
# [CV] normalize=False, alpha=10, fit_intercept=True ...................
# [CV]  normalize=True, alpha=1.0, fit_intercept=True, score=-3.762269, total=   0.0s
# [CV] normalize=True, alpha=1.0, fit_intercept=True ...................
# [CV]  normalize=True, alpha=100, fit_intercept=False, score=-4.799378, total=   0.0s
# [CV]  normalize=False, alpha=10, fit_intercept=True, score=-3.637362, total=   0.0s
# [CV] normalize=True, alpha=100, fit_intercept=False ..................
# [CV] normalize=False, alpha=10, fit_intercept=True ...................
# [CV]  normalize=True, alpha=100, fit_intercept=False, score=-4.297115, total=   0.0s
# [CV]  normalize=True, alpha=1.0, fit_intercept=True, score=-3.710119, total=   0.0s
# [CV] normalize=True, alpha=100, fit_intercept=False ..................
# [CV] normalize=True, alpha=1.0, fit_intercept=True ...................
# [CV]  normalize=False, alpha=10, fit_intercept=True, score=-3.730605, total=   0.0s
# [CV] normalize=False, alpha=10, fit_intercept=True ...................
# [CV]  normalize=True, alpha=100, fit_intercept=False, score=-4.652882, total=   0.0s
# [CV]  normalize=True, alpha=1.0, fit_intercept=True, score=-3.513917, total=   0.0s
# [CV] normalize=True, alpha=100, fit_intercept=False ..................
# [CV] normalize=True, alpha=1.0, fit_intercept=True ...................
# [CV]  normalize=False, alpha=10, fit_intercept=True, score=-3.647940, total=   0.0s
# [CV] normalize=False, alpha=10, fit_intercept=True ...................
# [CV]  normalize=True, alpha=100, fit_intercept=False, score=-4.851212, total=   0.0s
# [CV]  normalize=True, alpha=1.0, fit_intercept=True, score=-3.499478, total=   0.0s
# [CV] normalize=True, alpha=100, fit_intercept=False ..................
# [CV]  normalize=False, alpha=10, fit_intercept=True, score=-3.736121, total=   0.0s
# [CV] normalize=False, alpha=10, fit_intercept=True ...................
# [CV]  normalize=True, alpha=100, fit_intercept=False, score=-4.796509, total=   0.0s
# [CV] normalize=True, alpha=100, fit_intercept=False ..................
# [CV]  normalize=False, alpha=10, fit_intercept=True, score=-3.396128, total=   0.0s
# [CV] normalize=False, alpha=10, fit_intercept=True ...................
# [CV]  normalize=True, alpha=100, fit_intercept=False, score=-4.040213, total=   0.0s
# [CV] normalize=True, alpha=100, fit_intercept=False ..................
# [CV]  normalize=False, alpha=10, fit_intercept=True, score=-3.576722, total=   0.0s
# [CV] normalize=False, alpha=10, fit_intercept=True ...................
# [CV]  normalize=True, alpha=100, fit_intercept=False, score=-4.525648, total=   0.0s
# [CV] normalize=True, alpha=100, fit_intercept=False ..................
# [CV]  normalize=False, alpha=10, fit_intercept=True, score=-3.796296, total=   0.0s
# [CV] normalize=False, alpha=10, fit_intercept=True ...................
# [CV]  normalize=True, alpha=100, fit_intercept=False, score=-4.987281, total=   0.0s
# [CV] normalize=True, alpha=100, fit_intercept=False ..................
# [CV]  normalize=False, alpha=10, fit_intercept=True, score=-3.372649, total=   0.0s
# [CV] normalize=True, alpha=10, fit_intercept=False ...................
# [CV]  normalize=True, alpha=100, fit_intercept=False, score=-4.420825, total=   0.0s
# [CV] normalize=False, alpha=100, fit_intercept=False .................
# [CV]  normalize=True, alpha=10, fit_intercept=False, score=-4.118329, total=   0.0s
# [CV] normalize=True, alpha=10, fit_intercept=False ...................
# [CV]  normalize=False, alpha=100, fit_intercept=False, score=-4.549204, total=   0.0s
# [CV] normalize=False, alpha=100, fit_intercept=False .................
# [CV]  normalize=True, alpha=10, fit_intercept=False, score=-4.352673, total=   0.0s
# [CV] normalize=True, alpha=10, fit_intercept=False ...................
# [CV]  normalize=False, alpha=100, fit_intercept=False, score=-4.799378, total=   0.0s
# [CV] normalize=False, alpha=100, fit_intercept=False .................
# [CV]  normalize=True, alpha=10, fit_intercept=False, score=-4.079801, total=   0.0s
# [CV] normalize=True, alpha=10, fit_intercept=False ...................
# [CV]  normalize=False, alpha=100, fit_intercept=False, score=-4.297115, total=   0.0s
# [CV] normalize=False, alpha=100, fit_intercept=False .................
# [CV]  normalize=True, alpha=10, fit_intercept=False, score=-4.382469, total=   0.0s
# [CV] normalize=True, alpha=10, fit_intercept=False ...................
# [CV]  normalize=False, alpha=100, fit_intercept=False, score=-4.652882, total=   0.0s
# [CV]  normalize=True, alpha=10, fit_intercept=False, score=-4.430731, total=   0.0s
# [CV] normalize=False, alpha=100, fit_intercept=False .................
# [CV] normalize=True, alpha=10, fit_intercept=False ...................
# [CV]  normalize=False, alpha=100, fit_intercept=False, score=-4.851212, total=   0.0s
# [CV] normalize=False, alpha=100, fit_intercept=False .................
# [CV]  normalize=True, alpha=10, fit_intercept=False, score=-4.493046, total=   0.0s
# [CV] normalize=True, alpha=10, fit_intercept=False ...................
# [CV]  normalize=False, alpha=100, fit_intercept=False, score=-4.796509, total=   0.0s
# [CV] normalize=False, alpha=100, fit_intercept=False .................
# [CV]  normalize=True, alpha=10, fit_intercept=False, score=-3.636051, total=   0.0s
# [CV] normalize=True, alpha=10, fit_intercept=False ...................
# [CV]  normalize=False, alpha=100, fit_intercept=False, score=-4.040213, total=   0.0s
# [CV] normalize=False, alpha=100, fit_intercept=False .................
# [CV]  normalize=True, alpha=10, fit_intercept=False, score=-4.132482, total=   0.0s
# [CV] normalize=True, alpha=10, fit_intercept=False ...................
# [CV]  normalize=False, alpha=100, fit_intercept=False, score=-4.525648, total=   0.0s
# [CV] normalize=False, alpha=100, fit_intercept=False .................
# [CV]  normalize=True, alpha=10, fit_intercept=False, score=-4.613265, total=   0.0s
# [CV] normalize=True, alpha=10, fit_intercept=False ...................
# [CV]  normalize=False, alpha=100, fit_intercept=False, score=-4.987281, total=   0.0s
# [CV]  normalize=True, alpha=10, fit_intercept=False, score=-4.007575, total=   0.0s
# [CV] normalize=False, alpha=100, fit_intercept=False .................
# [CV] normalize=False, alpha=10, fit_intercept=False ..................
# [CV]  normalize=False, alpha=100, fit_intercept=False, score=-4.420825, total=   0.0s
# [CV]  normalize=False, alpha=10, fit_intercept=False, score=-4.118329, total=   0.0s
# [CV] normalize=False, alpha=10, fit_intercept=False ..................
# [CV]  normalize=False, alpha=10, fit_intercept=False, score=-4.352673, total=   0.0s
# Ridge(alpha=10, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001)
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:    1.0s finished

# %%
print model_cross_validation(best_ridge, X, y, mae_scorer_cv, 10)
# Out:
# 3.6038503309

# %%
lin_params = {
}

linear = LinearRegression()
best_linear = get_best_estimator(linear, 1, 10, mae_scorer_gs, lin_params)
# Out:
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV]  ................................................................
# [CV]  ................................................................
# [CV]  ................................................................
# [CV]  ................................................................
# [CV]  ................................................................
# [CV]  ................................................................
# [CV]  ................................................................
# [CV]  ................................................................
# [CV] ................................ , score=-3.304049, total=   0.1s
# [CV] ................................ , score=-3.896892, total=   0.1s
# [CV]  ................................................................
# [CV] ................................ , score=-3.768517, total=   0.0s
# [CV]  ................................................................
# [CV] ................................ , score=-3.404659, total=   0.0s
# [CV] ................................ , score=-3.623004, total=   0.1s
# [CV] ................................ , score=-3.703073, total=   0.1s
# [CV] ................................ , score=-3.797376, total=   0.1s
# [CV] ................................ , score=-3.796790, total=   0.1s
# [CV] ................................ , score=-3.592683, total=   0.1s
# [CV] ................................ , score=-3.359813, total=   0.1s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.0851s.) Setting batch_size=4.
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:    0.1s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:    0.1s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    0.2s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    0.2s finished

# %%
print model_cross_validation(linear, X, y, mae_scorer_cv, 10)
# Out:
# 3.61816601526

# %%
random_forest = RandomForestRegressor()

param_random_forest = {
    'n_estimators': [10, 50, 100, 200],
    'max_depth': [5, 8, 15, 25, 30, None],
    'min_samples_split': [2, 5, 10, 15, 50],
    'min_samples_leaf': [1, 2, 5, 10],
    'max_features': ['log2', 'sqrt', None]
}

# %%
best_forest = get_best_estimator(random_forest, 1, 10, mae_scorer_gs, param_random_forest)
# Out:
# Fitting 10 folds for each of 1440 candidates, totalling 14400 fits
# [CV] max_features=log2, min_samples_split=2, n_estimators=10, max_depth=5, min_samples_leaf=1
# [CV] max_features=log2, min_samples_split=2, n_estimators=10, max_depth=5, min_samples_leaf=1
# [CV] max_features=log2, min_samples_split=2, n_estimators=10, max_depth=5, min_samples_leaf=1
# [CV] max_features=log2, min_samples_split=2, n_estimators=10, max_depth=5, min_samples_leaf=1
# [CV] max_features=log2, min_samples_split=2, n_estimators=10, max_depth=5, min_samples_leaf=1
# [CV] max_features=log2, min_samples_split=2, n_estimators=10, max_depth=5, min_samples_leaf=1
# [CV] max_features=log2, min_samples_split=2, n_estimators=10, max_depth=5, min_samples_leaf=1
# [CV] max_features=log2, min_samples_split=2, n_estimators=10, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=2, n_estimators=10, max_depth=5, min_samples_leaf=1, score=-3.629583, total=   0.1s
# [CV]  max_features=log2, min_samples_split=2, n_estimators=10, max_depth=5, min_samples_leaf=1, score=-4.192558, total=   0.1s
# [CV] max_features=log2, min_samples_split=2, n_estimators=10, max_depth=5, min_samples_leaf=1
# [CV] max_features=log2, min_samples_split=2, n_estimators=10, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=2, n_estimators=10, max_depth=5, min_samples_leaf=1, score=-3.801452, total=   0.1s
# [CV]  max_features=log2, min_samples_split=2, n_estimators=10, max_depth=5, min_samples_leaf=1, score=-4.006452, total=   0.1s
# [CV]  max_features=log2, min_samples_split=2, n_estimators=10, max_depth=5, min_samples_leaf=1, score=-3.790801, total=   0.1s
# [CV] max_features=log2, min_samples_split=2, n_estimators=50, max_depth=5, min_samples_leaf=1
# [CV] max_features=log2, min_samples_split=2, n_estimators=50, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=2, n_estimators=10, max_depth=5, min_samples_leaf=1, score=-3.688953, total=   0.1s
# [CV]  max_features=log2, min_samples_split=2, n_estimators=10, max_depth=5, min_samples_leaf=1, score=-3.621776, total=   0.1s
# [CV]  max_features=log2, min_samples_split=2, n_estimators=10, max_depth=5, min_samples_leaf=1, score=-3.774651, total=   0.1s
# [CV] max_features=log2, min_samples_split=2, n_estimators=50, max_depth=5, min_samples_leaf=1
# [CV] max_features=log2, min_samples_split=2, n_estimators=50, max_depth=5, min_samples_leaf=1
# [CV] max_features=log2, min_samples_split=2, n_estimators=50, max_depth=5, min_samples_leaf=1
# [CV] max_features=log2, min_samples_split=2, n_estimators=50, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=2, n_estimators=10, max_depth=5, min_samples_leaf=1, score=-3.941080, total=   0.1s
# [CV]  max_features=log2, min_samples_split=2, n_estimators=10, max_depth=5, min_samples_leaf=1, score=-3.633186, total=   0.1s
# [CV] max_features=log2, min_samples_split=2, n_estimators=50, max_depth=5, min_samples_leaf=1
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1750s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    0.4s
# [CV] max_features=log2, min_samples_split=2, n_estimators=50, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=2, n_estimators=50, max_depth=5, min_samples_leaf=1, score=-3.787011, total=   0.5s
# [CV]  max_features=log2, min_samples_split=2, n_estimators=50, max_depth=5, min_samples_leaf=1, score=-3.819878, total=   0.5s
# [CV] max_features=log2, min_samples_split=2, n_estimators=100, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=2, n_estimators=50, max_depth=5, min_samples_leaf=1, score=-3.597183, total=   0.6s
# [CV]  max_features=log2, min_samples_split=2, n_estimators=50, max_depth=5, min_samples_leaf=1, score=-4.017735, total=   0.6s
# [CV] max_features=log2, min_samples_split=2, n_estimators=100, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=2, n_estimators=50, max_depth=5, min_samples_leaf=1, score=-3.722628, total=   0.5s
# [CV]  max_features=log2, min_samples_split=2, n_estimators=50, max_depth=5, min_samples_leaf=1, score=-4.044944, total=   0.6s
# [CV] max_features=log2, min_samples_split=2, n_estimators=100, max_depth=5, min_samples_leaf=1
# [CV] max_features=log2, min_samples_split=2, n_estimators=100, max_depth=5, min_samples_leaf=1
# [CV] max_features=log2, min_samples_split=2, n_estimators=100, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=2, n_estimators=50, max_depth=5, min_samples_leaf=1, score=-3.669772, total=   0.5s
# [CV] max_features=log2, min_samples_split=2, n_estimators=200, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=2, n_estimators=50, max_depth=5, min_samples_leaf=1, score=-3.846164, total=   0.5s
# [CV] max_features=log2, min_samples_split=2, n_estimators=50, max_depth=5, min_samples_leaf=1
# [CV] max_features=log2, min_samples_split=2, n_estimators=50, max_depth=5, min_samples_leaf=1
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:    0.9s
# [CV]  max_features=log2, min_samples_split=2, n_estimators=50, max_depth=5, min_samples_leaf=1, score=-3.562880, total=   0.5s
# [CV] max_features=log2, min_samples_split=2, n_estimators=200, max_depth=5, min_samples_leaf=1
# [CV] max_features=log2, min_samples_split=2, n_estimators=200, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=2, n_estimators=50, max_depth=5, min_samples_leaf=1, score=-3.647332, total=   0.5s
# [CV]  max_features=log2, min_samples_split=2, n_estimators=100, max_depth=5, min_samples_leaf=1, score=-3.572104, total=   1.0s
# [CV] max_features=log2, min_samples_split=2, n_estimators=100, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=2, n_estimators=100, max_depth=5, min_samples_leaf=1, score=-3.835546, total=   1.0s
# [CV] max_features=log2, min_samples_split=2, n_estimators=100, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=2, n_estimators=100, max_depth=5, min_samples_leaf=1, score=-3.638407, total=   1.0s
# [CV] max_features=log2, min_samples_split=2, n_estimators=100, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=2, n_estimators=100, max_depth=5, min_samples_leaf=1, score=-3.693005, total=   1.1s
# [CV]  max_features=log2, min_samples_split=2, n_estimators=100, max_depth=5, min_samples_leaf=1, score=-3.811212, total=   1.1s
# [CV] max_features=log2, min_samples_split=2, n_estimators=100, max_depth=5, min_samples_leaf=1
# [CV] max_features=log2, min_samples_split=2, n_estimators=100, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=2, n_estimators=100, max_depth=5, min_samples_leaf=1, score=-4.060621, total=   1.3s
# [CV] max_features=log2, min_samples_split=2, n_estimators=200, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=2, n_estimators=200, max_depth=5, min_samples_leaf=1, score=-3.551401, total=   2.3s
# [CV] max_features=log2, min_samples_split=2, n_estimators=200, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=2, n_estimators=100, max_depth=5, min_samples_leaf=1, score=-3.539608, total=   1.2s
# [CV]  max_features=log2, min_samples_split=2, n_estimators=100, max_depth=5, min_samples_leaf=1, score=-4.000520, total=   1.3s
# [CV] max_features=log2, min_samples_split=2, n_estimators=200, max_depth=5, min_samples_leaf=1
# [CV] max_features=log2, min_samples_split=5, n_estimators=10, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=2, n_estimators=100, max_depth=5, min_samples_leaf=1, score=-3.596502, total=   1.2s
# [CV]  max_features=log2, min_samples_split=2, n_estimators=100, max_depth=5, min_samples_leaf=1, score=-3.723012, total=   1.2s
# [CV] max_features=log2, min_samples_split=5, n_estimators=10, max_depth=5, min_samples_leaf=1
# [CV] max_features=log2, min_samples_split=5, n_estimators=10, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=5, n_estimators=10, max_depth=5, min_samples_leaf=1, score=-3.687490, total=   0.1s
# [CV]  max_features=log2, min_samples_split=5, n_estimators=10, max_depth=5, min_samples_leaf=1, score=-3.889797, total=   0.1s
# [CV] max_features=log2, min_samples_split=5, n_estimators=10, max_depth=5, min_samples_leaf=1
# [CV] max_features=log2, min_samples_split=5, n_estimators=10, max_depth=5, min_samples_leaf=1
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.0261s.) Setting batch_size=1.
# [CV]  max_features=log2, min_samples_split=5, n_estimators=10, max_depth=5, min_samples_leaf=1, score=-3.740081, total=   0.1s
# [CV] max_features=log2, min_samples_split=5, n_estimators=10, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=5, n_estimators=10, max_depth=5, min_samples_leaf=1, score=-4.112665, total=   0.1s
# [CV]  max_features=log2, min_samples_split=5, n_estimators=10, max_depth=5, min_samples_leaf=1, score=-4.027099, total=   0.1s
# [CV] max_features=log2, min_samples_split=5, n_estimators=10, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=5, n_estimators=10, max_depth=5, min_samples_leaf=1, score=-3.932065, total=   0.1s
# [CV] max_features=log2, min_samples_split=5, n_estimators=50, max_depth=5, min_samples_leaf=1
# [CV] max_features=log2, min_samples_split=5, n_estimators=10, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=5, n_estimators=10, max_depth=5, min_samples_leaf=1, score=-3.839352, total=   0.1s
# [CV] max_features=log2, min_samples_split=5, n_estimators=10, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=5, n_estimators=10, max_depth=5, min_samples_leaf=1, score=-3.692037, total=   0.1s
# [CV] max_features=log2, min_samples_split=5, n_estimators=10, max_depth=5, min_samples_leaf=1
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    3.9s
# [CV]  max_features=log2, min_samples_split=5, n_estimators=10, max_depth=5, min_samples_leaf=1, score=-3.646785, total=   0.1s
# [CV]  max_features=log2, min_samples_split=5, n_estimators=10, max_depth=5, min_samples_leaf=1, score=-3.634961, total=   0.1s
# [CV] max_features=log2, min_samples_split=5, n_estimators=50, max_depth=5, min_samples_leaf=1
# [CV] max_features=log2, min_samples_split=5, n_estimators=50, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=2, n_estimators=200, max_depth=5, min_samples_leaf=1, score=-3.816506, total=   2.4s
# [CV] max_features=log2, min_samples_split=2, n_estimators=200, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=2, n_estimators=200, max_depth=5, min_samples_leaf=1, score=-3.689110, total=   2.5s
# [CV] max_features=log2, min_samples_split=2, n_estimators=200, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=5, n_estimators=50, max_depth=5, min_samples_leaf=1, score=-3.534280, total=   0.5s
# [CV] max_features=log2, min_samples_split=5, n_estimators=50, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=5, n_estimators=50, max_depth=5, min_samples_leaf=1, score=-3.829819, total=   0.5s
# [CV]  max_features=log2, min_samples_split=5, n_estimators=50, max_depth=5, min_samples_leaf=1, score=-3.700976, total=   0.5s
# [CV] max_features=log2, min_samples_split=5, n_estimators=50, max_depth=5, min_samples_leaf=1
# [CV] max_features=log2, min_samples_split=5, n_estimators=50, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=5, n_estimators=50, max_depth=5, min_samples_leaf=1, score=-4.071763, total=   0.5s
# [CV] max_features=log2, min_samples_split=5, n_estimators=50, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=5, n_estimators=50, max_depth=5, min_samples_leaf=1, score=-4.057768, total=   0.6s
# [CV]  max_features=log2, min_samples_split=5, n_estimators=50, max_depth=5, min_samples_leaf=1, score=-3.715725, total=   0.6s
# [CV] max_features=log2, min_samples_split=5, n_estimators=50, max_depth=5, min_samples_leaf=1
# [CV] max_features=log2, min_samples_split=5, n_estimators=50, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=5, n_estimators=50, max_depth=5, min_samples_leaf=1, score=-3.601459, total=   0.6s
# [CV] max_features=log2, min_samples_split=5, n_estimators=50, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=2, n_estimators=200, max_depth=5, min_samples_leaf=1, score=-3.619671, total=   2.3s
# [CV] max_features=log2, min_samples_split=2, n_estimators=200, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=5, n_estimators=50, max_depth=5, min_samples_leaf=1, score=-3.543314, total=   0.6s
# [CV]  max_features=log2, min_samples_split=5, n_estimators=50, max_depth=5, min_samples_leaf=1, score=-3.843478, total=   0.6s
# [CV] max_features=log2, min_samples_split=5, n_estimators=100, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=2, n_estimators=200, max_depth=5, min_samples_leaf=1, score=-3.842503, total=   2.3s
# [CV] max_features=log2, min_samples_split=2, n_estimators=200, max_depth=5, min_samples_leaf=1
# [CV] max_features=log2, min_samples_split=5, n_estimators=100, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=2, n_estimators=200, max_depth=5, min_samples_leaf=1, score=-4.052108, total=   2.3s
# [CV] max_features=log2, min_samples_split=5, n_estimators=100, max_depth=5, min_samples_leaf=1
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed:    6.1s
# [CV]  max_features=log2, min_samples_split=5, n_estimators=50, max_depth=5, min_samples_leaf=1, score=-3.593822, total=   0.5s
# [CV] max_features=log2, min_samples_split=5, n_estimators=100, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=2, n_estimators=200, max_depth=5, min_samples_leaf=1, score=-4.016589, total=   2.2s
# [CV] max_features=log2, min_samples_split=5, n_estimators=100, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=2, n_estimators=200, max_depth=5, min_samples_leaf=1, score=-3.730721, total=   2.3s
# [CV] max_features=log2, min_samples_split=5, n_estimators=100, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=5, n_estimators=100, max_depth=5, min_samples_leaf=1, score=-3.560140, total=   1.1s
# [CV]  max_features=log2, min_samples_split=5, n_estimators=100, max_depth=5, min_samples_leaf=1, score=-4.060148, total=   1.1s
# [CV] max_features=log2, min_samples_split=5, n_estimators=100, max_depth=5, min_samples_leaf=1
# [CV] max_features=log2, min_samples_split=5, n_estimators=100, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=5, n_estimators=100, max_depth=5, min_samples_leaf=1, score=-3.793448, total=   1.1s
# [CV] max_features=log2, min_samples_split=5, n_estimators=100, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=5, n_estimators=100, max_depth=5, min_samples_leaf=1, score=-3.986599, total=   1.1s
# [CV] max_features=log2, min_samples_split=5, n_estimators=100, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=5, n_estimators=100, max_depth=5, min_samples_leaf=1, score=-3.724807, total=   1.2s
# [CV] max_features=log2, min_samples_split=5, n_estimators=200, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=5, n_estimators=100, max_depth=5, min_samples_leaf=1, score=-3.733746, total=   1.1s
# [CV] max_features=log2, min_samples_split=5, n_estimators=200, max_depth=5, min_samples_leaf=1
# [Parallel(n_jobs=-1)]: Done  62 tasks      | elapsed:    8.1s
# [CV]  max_features=log2, min_samples_split=2, n_estimators=200, max_depth=5, min_samples_leaf=1, score=-3.537262, total=   2.2s
# [CV] max_features=log2, min_samples_split=5, n_estimators=200, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=2, n_estimators=200, max_depth=5, min_samples_leaf=1, score=-3.572588, total=   2.3s
# [CV] max_features=log2, min_samples_split=5, n_estimators=200, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=5, n_estimators=100, max_depth=5, min_samples_leaf=1, score=-3.661006, total=   1.1s
# [CV] max_features=log2, min_samples_split=5, n_estimators=200, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=5, n_estimators=100, max_depth=5, min_samples_leaf=1, score=-3.533245, total=   1.1s
# [CV] max_features=log2, min_samples_split=5, n_estimators=200, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=5, n_estimators=100, max_depth=5, min_samples_leaf=1, score=-3.857375, total=   1.2s
# [CV] max_features=log2, min_samples_split=5, n_estimators=200, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=5, n_estimators=100, max_depth=5, min_samples_leaf=1, score=-3.558630, total=   1.1s
# [CV] max_features=log2, min_samples_split=5, n_estimators=200, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=5, n_estimators=200, max_depth=5, min_samples_leaf=1, score=-3.550877, total=   2.3s
# [CV]  max_features=log2, min_samples_split=5, n_estimators=200, max_depth=5, min_samples_leaf=1, score=-4.077613, total=   2.3s
# [CV] max_features=log2, min_samples_split=5, n_estimators=200, max_depth=5, min_samples_leaf=1
# [CV] max_features=log2, min_samples_split=5, n_estimators=200, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=5, n_estimators=200, max_depth=5, min_samples_leaf=1, score=-3.809169, total=   2.2s
# [CV] max_features=log2, min_samples_split=10, n_estimators=10, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=5, n_estimators=200, max_depth=5, min_samples_leaf=1, score=-3.744863, total=   2.2s
# [CV]  max_features=log2, min_samples_split=5, n_estimators=200, max_depth=5, min_samples_leaf=1, score=-3.999377, total=   2.2s
# [CV] max_features=log2, min_samples_split=10, n_estimators=10, max_depth=5, min_samples_leaf=1
# [CV] max_features=log2, min_samples_split=10, n_estimators=10, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=10, n_estimators=10, max_depth=5, min_samples_leaf=1, score=-3.593504, total=   0.1s
# [CV]  max_features=log2, min_samples_split=5, n_estimators=200, max_depth=5, min_samples_leaf=1, score=-3.721825, total=   2.2s
# [CV] max_features=log2, min_samples_split=10, n_estimators=10, max_depth=5, min_samples_leaf=1
# [CV] max_features=log2, min_samples_split=10, n_estimators=10, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=10, n_estimators=10, max_depth=5, min_samples_leaf=1, score=-4.008712, total=   0.1s
# [CV]  max_features=log2, min_samples_split=10, n_estimators=10, max_depth=5, min_samples_leaf=1, score=-3.797418, total=   0.1s
# [CV] max_features=log2, min_samples_split=10, n_estimators=10, max_depth=5, min_samples_leaf=1
# [CV] max_features=log2, min_samples_split=10, n_estimators=10, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=10, n_estimators=10, max_depth=5, min_samples_leaf=1, score=-3.723572, total=   0.1s
# [CV]  max_features=log2, min_samples_split=10, n_estimators=10, max_depth=5, min_samples_leaf=1, score=-4.122378, total=   0.1s
# [Parallel(n_jobs=-1)]: Done  75 tasks      | elapsed:   11.1s
# [CV] max_features=log2, min_samples_split=10, n_estimators=10, max_depth=5, min_samples_leaf=1
# [CV] max_features=log2, min_samples_split=10, n_estimators=10, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=5, n_estimators=200, max_depth=5, min_samples_leaf=1, score=-3.623218, total=   2.2s
# [CV]  max_features=log2, min_samples_split=10, n_estimators=10, max_depth=5, min_samples_leaf=1, score=-3.697822, total=   0.1s
# [CV] max_features=log2, min_samples_split=10, n_estimators=10, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=10, n_estimators=10, max_depth=5, min_samples_leaf=1, score=-3.831341, total=   0.1s
# [CV] max_features=log2, min_samples_split=10, n_estimators=50, max_depth=5, min_samples_leaf=1
# [CV] max_features=log2, min_samples_split=10, n_estimators=50, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=10, n_estimators=10, max_depth=5, min_samples_leaf=1, score=-3.606746, total=   0.1s
# [CV]  max_features=log2, min_samples_split=10, n_estimators=10, max_depth=5, min_samples_leaf=1, score=-3.916669, total=   0.1s
# [CV] max_features=log2, min_samples_split=10, n_estimators=50, max_depth=5, min_samples_leaf=1
# [CV] max_features=log2, min_samples_split=10, n_estimators=50, max_depth=5, min_samples_leaf=1
# [CV]  max_features=log2, min_samples_split=5, n_estimators=200, max_depth=5, min_samples_leaf=1, score=-3.560713, total=   2.2s
# [CV]  max_features=log2, min_samples_split=10, n_estimators=10, max_depth=5, min_samples_leaf=1, score=-3
total=   0.5s
# [CV] max_features=log2, min_samples_split=2, n_estimators=50, max_depth=5, min_samples_leaf=5
# [CV]  max_features=log2, min_samples_split=2, n_estimators=50, max_depth=5, min_samples_leaf=5, score=-3.738458, total=   0.5s
# [CV]  max_features=log2, min_samples_split=2, n_estimators=50, max_depth=5, min_samples_leaf=5, score=-4.049904, total=   0.6s
# [CV]  max_features=log2, min_samples_split=2, n_estimators=50, max_depth=5, min_samples_leaf=5, score=-3.725589, total=   0.6s
# [CV] max_features=log2, min_samples_split=2, n_estimators=50, max_depth=5, min_samples_leaf=5
# [CV] max_features=log2, min_samples_split=2, n_estimators=100, max_depth=5, min_samples_leaf=5
# [CV] max_features=log2, min_samples_split=2, n_estimators=100, max_depth=5, min_samples_leaf=5
# [CV]  max_features=log2, min_samples_split=2, n_estimators=50, max_depth=5, min_samples_leaf=5, score=-3.633147, total=   0.6s
# [CV]  max_features=log2, min_samples_split=2, n_estimators=50, max_depth=5, min_samples_leaf=5, score=-3.587050, total=   0.5s
# [CV] max_features=log2, min_samples_split=2, n_estimators=100, max_depth=5, min_samples_leaf=5
# [CV] max_features=log2, min_samples_split=2, n_estimators=100, max_depth=5, min_samples_leaf=5
# [CV]  max_features=log2, min_samples_split=2, n_estimators=50, max_depth=5, min_samples_leaf=5, score=-3.850896, total=   0.6s
# [CV] max_features=log2, min_samples_split=2, n_estimators=100, max_depth=5, min_samples_leaf=5
# [CV]  max_features=log2, min_samples_split=2, n_estimators=50, max_depth=5, min_samples_leaf=5, score=-3.553000, total=   0.5s
# [CV] max_features=log2, min_samples_split=2, n_estimators=100, max_depth=5, min_samples_leaf=5
# [CV]  max_features=log2, min_samples_split=50, n_estimators=200, max_depth=5, min_samples_leaf=2, score=-3.843164, total=   2.4s
# [CV] max_features=log2, min_samples_split=2, n_estimators=100, max_depth=5, min_samples_leaf=5
# [CV]  max_features=log2, min_samples_split=50, n_estimators=200, max_depth=5, min_samples_leaf=2, score=-3.610452, total=   2.4s
# [CV] max_features=log2, min_samples_split=2, n_estimators=100, max_depth=5, min_samples_leaf=5
# [CV]  max_features=log2, min_samples_split=2, n_estimators=100, max_depth=5, min_samples_leaf=5, score=-3.542576, total=   1.1s
# [CV]  max_features=log2, min_samples_split=2, n_estimators=100, max_depth=5, min_samples_leaf=5, score=-4.083161, total=   1.1s
# [CV] max_features=log2, min_samples_split=2, n_estimators=100, max_depth=5, min_samples_leaf=5
# [CV] max_features=log2, min_samples_split=2, n_estimators=100, max_depth=5, min_samples_leaf=5
# [CV]  max_features=log2, min_samples_split=2, n_estimators=100, max_depth=5, min_samples_leaf=5, score=-3.816711, total=   1.1s
# [CV] max_features=log2, min_samples_split=2, n_estimators=200, max_depth=5, min_samples_leaf=5
# [CV]  max_features=log2, min_samples_split=2, n_estimators=100, max_depth=5, min_samples_leaf=5, score=-3.718797, total=   1.1s
# [CV] max_features=log2, min_samples_split=2, n_estimators=200, max_depth=5, min_samples_leaf=5
# [CV]  max_features=log2, min_samples_split=2, n_estimators=100, max_depth=5, min_samples_leaf=5, score=-4.031743, total=   1.2s
# [CV]  max_features=log2, min_samples_split=2, n_estimators=100, max_depth=5, min_samples_leaf=5, score=-3.739952, total=   1.1s
# [CV] max_features=log2, min_samples_split=2, n_estimators=200, max_depth=5, min_samples_leaf=5
# [CV] max_features=log2, min_samples_split=2, n_estimators=200, max_depth=5, min_samples_leaf=5
# [Parallel(n_jobs=-1)]: Done 424 tasks      | elapsed:   59.8s
# [CV]  max_features=log2, min_samples_split=2, n_estimators=100, max_depth=5, min_samples_leaf=5, score=-3.624365, total=   1.2s
# [CV] max_features=log2, min_samples_split=2, n_estimators=200, max_depth=5, min_samples_leaf=5
# [CV]  max_features=log2, min_samples_split=2, n_estimators=100, max_depth=5, min_samples_leaf=5, score=-3.540669, total=   1.1s
# [CV] max_features=log2, min_samples_split=2, n_estimators=200, max_depth=5, min_samples_leaf=5
# [CV]  max_features=log2, min_samples_split=2, n_estimators=100, max_depth=5, min_samples_leaf=5, score=-3.857733, total=   1.1s
# [CV] max_features=log2, min_samples_split=2, n_estimators=200, max_depth=5, min_samples_leaf=5
# [CV]  max_features=log2, min_samples_split=2, n_estimators=100, max_depth=5, min_samples_leaf=5, score=-3.595089, total=   1.1s
# [CV] max_features=log2, min_samples_split=2, n_estimators=200, max_depth=5, min_samples_leaf=5
# [CV]  max_features=log2, min_samples_split=2, n_estimators=200, max_depth=5, min_samples_leaf=5, score=-4.011831, total=   2.1s
# [CV]  max_features=log2, min_samples_split=2, n_estimators=200, max_depth=5, min_samples_leaf=5, score=-3.542617, total=   2.2s
# [CV]  max_features=log2, min_samples_split=2, n_estimators=200, max_depth=5, min_samples_leaf=5, score=-3.810345, total=   2.2s
# [CV] max_features=log2, min_samples_split=2, n_estimators=200, max_depth=5, min_samples_leaf=5
# [CV] max_features=log2, min_samples_split=2, n_estimators=200, max_depth=5, min_samples_leaf=5
# [CV] max_features=log2, min_samples_split=5, n_estimators=10, max_depth=5, min_samples_leaf=5
# [CV]  max_features=log2, min_samples_split=2, n_estimators=200, max_depth=5, min_samples_leaf=5, score=-4.050815, total=   2.2s
# [CV] max_features=log2, min_samples_split=5, n_estimators=10, max_depth=5, min_samples_leaf=5
# [CV]  max_features=log2, min_samples_split=5, n_estimators=10, max_depth=5, min_samples_leaf=5, score=-3.654023, total=   0.1s
# [CV] max_features=log2, min_samples_split=5, n_estimators=10, max_depth=5, min_samples_leaf=5
# [CV]  max_features=log2, min_samples_split=5, n_estimators=10, max_depth=5, min_samples_leaf=5, score=-4.116274, total=   0.1s
# [CV] max_features=log2, min_samples_split=5, n_estimators=10, max_depth=5, min_samples_leaf=5
# [CV]  max_features=log2, min_samples_split=5, n_estimators=10, max_depth=5, min_samples_leaf=5, score=-3.775628, total=   0.1s
# [CV] max_features=log2, min_samples_split=5, n_estimators=10, max_depth=5, min_samples_leaf=5
# [CV]  max_features=log2, min_samples_split=5, n_estimators=10, max_depth=5, min_samples_leaf=5, score=-4.038567, total=   0.1s
# [CV] max_features=log2, min_samples_split=5, n_estimators=10, max_depth=5, min_samples_leaf=5
# [CV]  max_features=log2, min_samples_split=5, n_estimators=10, max_depth=5, min_samples_leaf=5, score=-3.726858, total=   0.1s
# [CV] max_features=log2, min_samples_split=5, n_estimators=10, max_depth=5, min_samples_leaf=5
# [CV]  max_features=log2, min_samples_split=5, n_estimators=10, max_depth=5, min_samples_leaf=5, score=-3.748476, total=   0.1s
# [CV] max_features=log2, min_samples_split=5, n_estimators=10, max_depth=5, min_samples_leaf=5
# [CV]  max_features=log2, min_samples_split=5, n_estimators=10, max_depth=5, min_samples_leaf=5, score=-3.655497, total=   0.1s
# [CV] max_features=log2, min_samples_split=5, n_estimators=10, max_depth=5, min_samples_leaf=5
# [CV]  max_features=log2, min_samples_split=2, n_estimators=200, max_depth=5, min_samples_leaf=5, score=-3.729473, total=   2.2s
# [CV] max_features=log2, min_samples_split=5, n_estimators=10, max_depth=5, min_samples_leaf=5
# [CV]  max_features=log2, min_samples_split=5, n_estimators=10, max_depth=5, min_samples_leaf=5, score=-3.605728, total=   0.1s
# [CV] max_features=log2, min_samples_split=5, n_estimators=50, max_depth=5, min_samples_leaf=5
# [CV]  max_features=log2, min_samples_split=2, n_estimators=200, max_depth=5, min_samples_leaf=5, score=-3.726766, total=   2.2s
# [CV]  max_features=log2, min_samples_split=2, n_estimators=200, max_depth=5, min_samples_leaf=5, score=-3.530011, total=   2.2s
# [CV]  max_features=log2, min_samples_split=2, n_estimators=200, max_depth=5, min_samples_leaf=5, score=-3.651279, total=   2.2s
# [CV] max_features=log2, min_samples_split=5, n_estimators=50, max_depth=5, min_samples_leaf=5
# [CV] max_features=log2, min_samples_split=5, n_estimators=50, max_depth=5, min_samples_leaf=5
# [CV] max_features=log2, min_samples_split=5, n_estimators=50, max_depth=5, min_samples_leaf=5
# [CV]  max_features=log2, min_samples_split=5, n_estimators=10, max_depth=5, min_samples_leaf=5, score=-3.938282, total=   0.1s
# [CV] max_features=log2, min_samples_split=5, n_estimators=50, max_depth=5, min_samples_leaf=5
# [CV]  max_features=log2, min_samples_split=5, n_estimators=10, max_depth=5, min_samples_leaf=5, score=-3.625482, total=   0.1s
# [CV] max_features=log2, min_samples_split=5, n_estimators=50, max_depth=5, min_samples_leaf=5
# [CV]  max_features=log2, min_samples_split=5, n_estimators=50, max_depth=5, min_samples_leaf=5, score=-3.581529, total=   0.6s
# [CV] max_features=log2, min_samples_split=5, n_estimators=50, max_depth=5, min_samples_leaf=5
# [CV]  max_features=log2, min_samples_split=5, n_estimators=50, max_depth=5, min_samples_leaf=5, score=-4.074881, total=   0.6s
# [CV] max_features=log2, min_samples_split=5, n_estimators=50, max_depth=5, min_samples_leaf=5
# [CV]  max_features=log2, min_samples_split=5, n_estimators=50, max_depth=5, min_samples_leaf=5, score=-3.764510, total=   0.6s
# [CV]  max_features=log2, min_samples_split=5, n_estimators=50, max_depth=5, min_samples_leaf=5, score=-3.993713, total=   0.6s
# [CV] max_features=log2, min_samples_split=5, n_estimators=50, max_depth=5, min_samples_leaf=5
# [CV] max_features=log2, min_samples_split=5, n_estimators=50, max_depth=5, min_samples_leaf=5
# [CV]  max_features=log2, min_samples_split=5, n_estimators=50, max_depth=5, min_samples_leaf=5, score=-3.754819, total=   0.6s
# [CV] max_features=log2, min_samples_split=5, n_estimators=100, max_depth=5, min_samples_leaf=5
# [CV]  max_features=log2, min_samples_split=5, n_estimators=50, max_depth=5, min_samples_leaf=5, score=-3.729319, total=   0.6s
# [CV] max_features=log2, min_samples_split=5, n_estimators=100, max_depth=5, min_samples_leaf=5
# [Parallel(n_jobs=-1)]: Done 453 tasks      | elapsed:  1.1min
# [CV]  max_features=log2, min_samples_split=5, n_estimators=50, max_depth=5, min_samples_leaf=5, score=-3.678944, total=   0.6s
# [CV] max_features=log2, min_samples_split=5, n_estimators=100, max_depth=5, min_samples_leaf=5
# [CV]  max_features=log2, min_samples_split=5, n_estimators=50, max_depth=5, min_samples_leaf=5, score=-3.546597, total=   0.6s
# [CV]  max_features=log2, min_samples_split=5, n_estimators=50, max_depth=5, min_samples_leaf=5, score=-3.849672, total=   0.6s
# [CV] max_features=log2, min_samples_split=5, n_estimators=100, max_depth=5, min_samples_leaf=5
# [CV] max_features=log2, min_samples_split=5, n_estimators=100, max_depth=5, min_samples_leaf=5
# [CV]  max_features=log2, min_samples_split=5, n_estimators=50, max_depth=5, min_samples_leaf=5, score=-3.583743, total=   0.6s
# [CV] max_features=log2, min_samples_split=5, n_estimators=100, max_depth=5, min_samples_leaf=5
# [CV]  max_features=log2, min_samples_split=2, n_estimators=200, max_depth=5, min_samples_leaf=5, score=-3.568501, total=   2.4s
# [CV]  max_features=log2, min_samples_split=2, n_estimators=200, max_depth=5, min_samples_leaf=5, score=-3.829573, total=   2.4s
# [CV] max_features=log2, min_samples_split=5, n_estimators=100, max_depth=5, min_samples_leaf=5
# [CV] max_features=log2, min_samples_split=5, n_estimators=100, max_depth=5, min_samples_leaf=5
# [CV]  max_features=log2, min_samples_split=5, n_estimators=100, max_depth=5, min_samples_leaf=5, score=-3.557639, total=   1.1s
# [CV] max_features=log2, min_samples_split=5, n_estimators=100, max_depth=5, min_samples_leaf=5
# [CV]  max_features=log2, min_samples_split=5, n_estimators=100, max_depth=5, min_samples_leaf=5, score=-4.048735, total=   1.1s
# [CV] max_features=log2, min_samples_split=5, n_estimators=100, max_depth=5, min_samples_leaf=5
# [CV]  max_features=log2, min_samples_split=5, n_estimators=100, max_depth=5, min_samples_leaf=5, score=-3.822243, total=   1.1s
# [CV] max_features=log2, min_samples_split=5, n_estimators=200, max_depth=5, min_samples_leaf=5
# [CV]  max_features=log2, min_samples_split=5, n_estimators=100, max_depth=5, min_samples_leaf=5, score=-3.700710, total=   1.1s
# [CV] max_features=log2, min_samples_split=5, n_estimators=200, max_depth=5, min_samples_leaf=5
# [CV]  max_features=log2, min_samples_split=5, n_estimators=100, max_depth=5, min_samples_leaf=5, score=-4.010195, total=   1.1s
# [CV]  max_features=log2, min_samples_split=5, n_estimators=100, max_depth=5, min_samples_leaf=5, score=-3.732103, total=   1.1s
# [CV] max_features=log2, min_samples_split=5, n_estimators=200, max_depth=5, min_samples_leaf=5
# [CV] max_features=log2, min_samples_split=5, n_estimators=200, max_depth=5, min_samples_leaf=5
# [CV]  max_features=log2, min_samples_split=5, n_estimators=100, max_depth=5, min_samples_leaf=5, score=-3.651434, total=   1.1s
# [CV]  max_features=log2, min_samples_split=5, n_estimators=100, max_depth=5, min_samples_leaf=5, score=-3.548583, total=   1.1s
# [CV] max_features=log2, min_samples_split=5, n_estimators=200, max_depth=5, min_samples_leaf=5
# [CV] max_features=log2, min_samples_split=5, n_estimators=200, max_depth=5, min_samples_leaf=5
# [CV]  max_features=log2, min_samples_split=5, n_estimators=100, max_depth=5, min_samples_leaf=5, score=-3.851686, total=   1.1s
# [CV]  max_features=log2, min_samples_split=5, n_estimators=100, max_depth=5, min_samples_leaf=5, score=-3.590688, total=   1.0s
# [CV] max_features=log2, min_samples_split=5, n_estimators=200, max_depth=5, min_samples_leaf=5
# [CV] max_features=log2, min_samples_split=5, n_estimators=200, max_depth=5, min_samples_leaf=5

# %%
print model_cross_validation(best_forest, X, y, mae_scorer_cv, 10)
# Out:
# 3.83106378686

# %%
# tree = DecisionTreeRegressor()

# param_tree = {
#     'estimator__n_estimators': [1, 5, 10, 50, 100, 300, 500, 1000],
#     'estimator__max_depth': [5, 8, 15, 25, 30, None],
#     'estimator__min_samples_split': [2, 5, 10, 15, 100],
#     'estimator__min_samples_leaf': [1, 2, 5, 10],
#     'estimator__max_features': ['log2', 'sqrt', None, 10]
# }

# best_knn = get_best_estimator(tree, 1, 10, mae_scorer_gs, param_random_forest)

# %%
# print model_cross_validation(best_knn.estimator_, X, y, mae_scorer_cv, 10)

# %%
svr = SVR()

svr_parameters = {
    'C': [0.001, 0.01, 0.1, 1.0, 10.0, 100.0, 1000.0],
    'kernel': ['rbf', 'poly'],
    'epsilon': [0.0, 0.1, 0.2, 0.5, 1.0]
}


best_svr = get_best_estimator(svr, 1, 10, mae_scorer_gs, svr_parameters)

# %%
print model_cross_validation(svr, X, y, mae_scorer_cv, 10)
# Out:
# 5.80977421933

# %%
bagging = BaggingRegressor(base_estimator=best_ridge, n_estimators=50, random_state=42)

# %%
bagging.fit(X_train, y_train)
# Out:
# BaggingRegressor(base_estimator=Ridge(alpha=10, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001),
#          bootstrap=True, bootstrap_features=False, max_features=1.0,
#          max_samples=1.0, n_estimators=50, n_jobs=1, oob_score=False,
#          random_state=42, verbose=0, warm_start=False)

# %%
print model_cross_validation(bagging, X, y, mae_scorer_cv, 10)
# Out:
# 3.60498900667
